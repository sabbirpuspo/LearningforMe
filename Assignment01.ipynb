# %% [markdown]
# <a href="https://colab.research.google.com/github/sabbirpuspo/LearningforMe/blob/main/Assignment01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to Data Science Course")
# Out:
# Welcome to Data Science Course

# %%
# Discuss about print()

print(10+20, "sabbir", "\n", "Data", "\t", "Science")

print("Summation of 10 and 5 is:", 10 + 5, "\n", "Division:", 10 / 5, "\n", "Multiplecation:", 10 * 5, "\n", "Subtraction:", 10 -5 )
# Out:
# 30 sabbir
#  Data 	 Science
# Summation of 10 and 5 is: 15
#  Division: 2.0
#  Multiplecation: 50
#  Subtraction: 5

# %%
# Different types of values
number1 = 20
number2 = 30
Summation = number1 + number2
print(Summation)
Division = number1 / number2
print(Division)
Multiplecation = number1 * number2
print(Multiplecation)
Subtraction = number1 - number2
print(Subtraction)
Percentage = number1 % number2
print(Percentage)

"\n"

#Floating and Integer values

number1 = 200.57
number2 = 35.88
Summation = number1 + number2
print(Summation)

#Floating: 51.45
#Integer: 51

int = number1 // number2
print("Integer part:", int)
# Out:
# 50
# 0.6666666666666666
# 600
# -10
# 20
# 236.45
# Integer part: 5.0

# %%
#Input
number1 = input("Enter your first number: ")
number2 = input("Enter your second number: ")
number1 = int(number1)
number2 = int(number2)
print("Summation:", number1 + number2)
print("Subtraction:", number1 - number2)
print("Multiplecation:", number1 * number2)
print("Division:", number1 / number2)
print("Percentage:", number1 % number2)
# Out:
# Enter your first number: 50
# Enter your second number: 20
# Summation: 70
# Subtraction: 30
# Multiplecation: 1000
# Division: 2.5
# Percentage: 10

# %%
#data type identification

a = 555.7544
b = 9964
c = "James007"
print(type(c))
# Out:
# <class 'str'>

# %%
# Comparision Operator
number1 = 100
number2 = 300
print(number1 == number2)
print(number1 != number2)
print(number1 > number2)
print(number1 < number2)
print(number1 >= number2)
print(number1 <= number2)
# Out:
# False
# True
# False
# True
# False
# True

# %%
# Conditional Operator
number = 200
if number % 2 == 0:
  print("Number is even")
if number % 2 == 1:
  print("Number is odd")
# Out:
# Number is even
